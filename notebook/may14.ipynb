# %%
# Read npz file
import numpy as np
import os

fpath = "/scratch/railabs/ld258/dataset/public_dataset/CVPR_seg_2025/3D_val_npz/CT_AbdTumor_case_00460.npz"
data = np.load(fpath, allow_pickle=True)
data['text_prompts']
# Out:
# array({'1': 'Focal kidney abnormalities visualized in cross-sectional abdominal scans', 'instance_label': 1},
#       dtype=object)
